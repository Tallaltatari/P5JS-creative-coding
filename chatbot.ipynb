# %% [markdown]
# <a href="https://colab.research.google.com/github/Tallaltatari/P5JS-creative-coding/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Description: This is a chatbot program

# %%
#import the library
from nltk.chat.util import Chat, reflections

# %%
pairs = [
    ['my name is (.*)', ['hi %1']],
    ['(hi|hello|hey|holla|hola)', ['hey there', 'hi there', 'hey']],
    ['(.*) in (.*) is fun', ['%1 in %2 is indeed fun']],
    ['(.*)(location|city) ?', 'Tokyo, Japan'],
    ['(.*)created you?', ['Tallal did using NLTK']],
    ['how is the weather in (.*)', ['the weather in %1 is amazing like always']]
]

# %%
chat = Chat(pairs, reflections)
chat.converse()
# Out:
# >how is the weather
# None
# >how is the weather berlin
# None
# >how is the weather in tokyo
# the weather in tokyo is amazing like always
# >who created you
# Tallal did using NLTK
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-14-323297157.py in <cell line: 0>()
#       1 chat = Chat(pairs, reflections)
# ----> 2 chat.converse()
#
# /usr/local/lib/python3.11/dist-packages/nltk/chat/util.py in converse(self, quit)
#     116             user_input = quit
#     117             try:
# --> 118                 user_input = input(">")
#     119             except EOFError:
#     120                 print(user_input)
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# ...
